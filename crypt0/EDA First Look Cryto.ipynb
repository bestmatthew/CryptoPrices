# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt 
import seaborn as sns
np.set_printoptions(suppress=True)

# %%
btc = pd.read_csv('coin_Bitcoin.csv')  #first thing we do is 'load' each csv data file into a pandas df
btc['Swing'] = btc['High'] - btc['Low']  #I'm adding a col "Swing" to show the difference between the daily high/low
btc['Percent'] = btc['High'] / btc['Low'] #I've added another col "Percent" to show the quotient of daily high/low prices
btc                                        # variable for the Bitcoin pandas df with its added columns is called

btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2857  2858  Bitcoin    BTC  2021-02-23 23:59:59  54204.929756  45290.590268
# 2858  2859  Bitcoin    BTC  2021-02-24 23:59:59  51290.136695  47213.498162
# 2859  2860  Bitcoin    BTC  2021-02-25 23:59:59  51948.966982  47093.853019
# 2860  2861  Bitcoin    BTC  2021-02-26 23:59:59  48370.785260  44454.842114
# 2861  2862  Bitcoin    BTC  2021-02-27 23:59:59  48253.270101  45269.025766
#
#               Open         Close        Volume     Marketcap        Swing  \
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09    13.488007
# 1       144.000000    139.000000  0.000000e+00  1.542813e+09    12.879990
# 2       139.000000    116.989998  0.000000e+00  1.298955e+09    32.169998
# 3       116.379997    105.209999  0.000000e+00  1.168517e+09    33.318100
# 4       106.250000     97.750000  0.000000e+00  1.085995e+09    29.028000
# ...            ...           ...           ...           ...          ...
# 2857  54204.929756  48824.426869  1.061025e+11  9.099259e+11  8914.339488
# 2858  48835.087661  49705.333316  6.369552e+10  9.263931e+11  4076.638533
# 2859  49709.082425  47093.853019  5.450657e+10  8.777661e+11  4855.113963
# 2860  47180.464054  46339.760083  3.509679e+11  8.637523e+11  3915.943146
# 2861  46344.772237  46188.451275  4.591095e+10  8.609781e+11  2984.244335
#
#        Percent
# 0     1.100657
# 1     1.096083
# 2     1.298645
# 3     1.361047
# 4     1.366979
# ...        ...
# 2857  1.196825
# 2858  1.086345
# 2859  1.103094
# 2860  1.088088
# 2861  1.065922
#
# [2862 rows x 12 columns]

# %%
## more data I can "create" from this CSV like the 
# "Diff", Daily High - Daily Low
 #"Swing", Daily Open - Daily Close  ?? useful?

# %%
ltc = pd.read_csv('coin_Litecoin.csv')
ltc['Swing'] = ltc['High'] - ltc['Low'] 
ltc['Percent'] = ltc['High'] / ltc['Low']
ltc
# Out:
#        SNo      Name Symbol                 Date        High         Low  \
# 0        1  Litecoin    LTC  2013-04-29 23:59:59    4.573600    4.225640
# 1        2  Litecoin    LTC  2013-04-30 23:59:59    4.572380    4.168960
# 2        3  Litecoin    LTC  2013-05-01 23:59:59    4.356860    3.520290
# 2759  0.473563  1.435902e+10  2.150165e+10  0.191687  1.505368
# 2760  0.471832  8.015469e+09  2.142305e+10  0.044611  1.098098
# 2761  0.434524  5.952354e+09  1.972912e+10  0.053414  1.124477
# 2762  0.427900  6.476254e+09  1.942839e+10  0.034881  1.083939
# 2763  0.437809  4.756623e+09  1.987829e+10  0.029692  1.069390
#
# [2764 rows x 12 columns]

# %%
xmr = pd.read_csv('coin_Monero.csv')
xmr['Swing'] = xmr['High'] - xmr['Low'] 
xmr['Percent'] = xmr['High'] / xmr['Low']
xmr
# Out:
#        SNo    Name Symbol                 Date        High         Low  \
# 0        1  Monero    XMR  2014-05-22 23:59:59    2.188880    1.359090
# 1        2  Monero    XMR  2014-05-23 23:59:59    3.434370    2.051040
# 2        3  Monero    XMR  2014-05-24 23:59:59    4.014240    2.617780
# 3        4  Monero    XMR  2014-05-25 23:59:59    4.043030    2.803300
# 4        5  Monero    XMR  2014-05-26 23:59:59    3.762350    2.312020
# ...    ...     ...    ...                  ...         ...         ...
# 2468  2469  Monero    XMR  2021-02-23 23:59:59  225.015462  171.288990
# 2469  2470  Monero    XMR  2021-02-24 23:59:59  224.976032  198.768041
# 2470  2471  Monero    XMR  2021-02-25 23:59:59  218.282977  197.548116
# 2471  2472  Monero    XMR  2021-02-26 23:59:59  217.347069  194.115854
# 2472  2473  Monero    XMR  2021-02-27 23:59:59  222.826730  204.158959
#
#             Open       Close        Volume     Marketcap      Swing   Percent
# 0       1.589400    2.095580  1.329180e+05  1.855608e+06   0.829790  1.610548
# 1       2.051040    2.963020  2.668520e+05  2.692180e+06   1.383330  1.674453
# 2       2.920390    3.702450  2.480280e+05  3.456658e+06   1.396460  1.533452
# 3       4.043030    3.138560  2.835450e+05  2.993339e+06   1.239730  1.442239
# 4       3.218970    3.021860  2.201480e+05  2.946133e+06   1.450330  1.627300
# ...          ...         ...           ...           ...        ...       ...
# 2468  224.992714  219.531057  1.161681e+09  3.917993e+09  53.726472  1.313660
# 2469  219.575963  205.749129  8.610354e+08  3.672199e+09  26.207991  1.131852
# 2470  205.743357  197.548116  6.282454e+08  3.526000e+09  20.734861  1.104961
# 2471  197.732345  204.104497  7.505161e+08  3.643191e+09  23.231215  1.119677
# 2472  204.158959  209.310812  6.800109e+08  3.736292e+09  18.667771  1.091437
#
# [2473 rows x 12 columns]

# %%
eth = pd.read_csv('coin_Ethereum.csv')
eth['Swing'] = eth['High'] - eth['Low'] 
eth['Percent'] = eth['High'] / eth['Low']
eth
# Out:
#        SNo      Name Symbol                 Date         High          Low  \
# 0        1  Ethereum    ETH  2015-08-08 23:59:59     2.798810     0.714725
# 1        2  Ethereum    ETH  2015-08-09 23:59:59     0.879810     0.629191
# 2        3  Ethereum    ETH  2015-08-10 23:59:59     0.729854     0.636546
# 3        4  Ethereum    ETH  2015-08-11 23:59:59     1.131410     0.663235
# 4        5  Ethereum    ETH  2015-08-12 23:59:59     1.289940     0.883608
# ...    ...       ...    ...                  ...          ...          ...
# 2026  2027  Ethereum    ETH  2021-02-23 23:59:59  1781.409018  1378.840907
# 2027  2028  Ethereum    ETH  2021-02-24 23:59:59  1710.983795  1511.018963
# 2028  2029  Ethereum    ETH  2021-02-25 23:59:59  1670.224062  1465.058946
# 2029  2030  Ethereum    ETH  2021-02-26 23:59:59  1559.028891  1407.979253
# 2030  2031  Ethereum    ETH  2021-02-27 23:59:59  1524.932428  1433.786929
#
#              Open        Close        Volume     Marketcap       Swing  \
# 0        2.793760     0.753325  6.741880e+05  4.548689e+07    2.084085
# 1        0.706136     0.701897  5.321700e+05  4.239957e+07    0.250619
# 2        0.713989     0.708448  4.052830e+05  4.281836e+07    0.093308
# 3        0.708087     1.067860  1.463100e+06  6.456929e+07    0.468175
# 4        1.058750     1.217440  2.150620e+06  7.364501e+07    0.406332
# ...           ...          ...           ...           ...         ...
# 2026  1781.409018  1570.203925  5.202986e+10  1.802510e+11  402.568110
# 2027  1571.476497  1626.575705  3.132900e+10  1.867440e+11  199.964832
# 2028  1625.393882  1475.703735  2.448168e+10  1.694427e+11  205.165115
# 2029  1478.653270  1446.033650  3.143600e+10  1.660555e+11  151.049638
# 2030  1446.929455  1459.973121  2.074210e+10  1.676759e+11   91.145499
#
#        Percent
# 0     3.915926
# 1     1.398319
# 2     1.146585
# 3     1.705896
# 4     1.459856
# ...        ...
# 2026  1.291961
# 2027  1.132338
# 2028  1.140039
# 2029  1.107281
# 2030  1.063570
#
# [2031 rows x 12 columns]

# %%
def getavgl(data):
    avgs = []
    for x in data:
        avgs.append(np.mean(x['Low']))
    return avgs

def getavgh(data):
    avgs = []
    for x in data:
        avgs.append(np.mean(x['High']))
    return avgs

# %%
coins = btc, ltc, xrp, xmr, eth      #variable that holds all data for the 5 dataframes

coins
# Out:
# (       SNo     Name Symbol                 Date          High           Low  \
#  0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
#  1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
#  2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
#  3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
#  4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
#  ...    ...      ...    ...                  ...           ...           ...
#  2857  2858  Bitcoin    BTC  2021-02-23 23:59:59  54204.929756  45290.590268
#  2858  2859  Bitcoin    BTC  2021-02-24 23:59:59  51290.136695  47213.498162
#  2859  2860  Bitcoin    BTC  2021-02-25 23:59:59  51948.966982  47093.853019
#  2860  2861  Bitcoin    BTC  2021-02-26 23:59:59  48370.785260  44454.842114
#  2861  2862  Bitcoin    BTC  2021-02-27 23:59:59  48253.270101  45269.025766
#
#                Open         Close        Volume     Marketcap        Swing  \
#  0       134.444000    144.539993  0.000000e+00  1.603769e+09    13.488007
#  1       144.000000    139.000000  0.000000e+00  1.542813e+09    12.879990
#  2       139.000000    116.989998  0.000000e+00  1.298955e+09    32.169998
#  3       116.379997    105.209999  0.000000e+00  1.168517e+09    33.318100
#  4       106.250000     97.750000  0.000000e+00  1.085995e+09    29.028000
#         SNo      Name Symbol                 Date         High          Low  \
#  0        1  Ethereum    ETH  2015-08-08 23:59:59     2.798810     0.714725
#  1        2  Ethereum    ETH  2015-08-09 23:59:59     0.879810     0.629191
#  2        3  Ethereum    ETH  2015-08-10 23:59:59     0.729854     0.636546
#  3        4  Ethereum    ETH  2015-08-11 23:59:59     1.131410     0.663235
#  4        5  Ethereum    ETH  2015-08-12 23:59:59     1.289940     0.883608
#  ...    ...       ...    ...                  ...          ...          ...
#  2026  2027  Ethereum    ETH  2021-02-23 23:59:59  1781.409018  1378.840907
#  2027  2028  Ethereum    ETH  2021-02-24 23:59:59  1710.983795  1511.018963
#  2028  2029  Ethereum    ETH  2021-02-25 23:59:59  1670.224062  1465.058946
#  2029  2030  Ethereum    ETH  2021-02-26 23:59:59  1559.028891  1407.979253
#  2030  2031  Ethereum    ETH  2021-02-27 23:59:59  1524.932428  1433.786929
#
#               Open        Close        Volume     Marketcap       Swing  \
#  0        2.793760     0.753325  6.741880e+05  4.548689e+07    2.084085
#  1        0.706136     0.701897  5.321700e+05  4.239957e+07    0.250619
#  2        0.713989     0.708448  4.052830e+05  4.281836e+07    0.093308
#  3        0.708087     1.067860  1.463100e+06  6.456929e+07    0.468175
#  4        1.058750     1.217440  2.150620e+06  7.364501e+07    0.406332
#  ...           ...          ...           ...           ...         ...
#  2026  1781.409018  1570.203925  5.202986e+10  1.802510e+11  402.568110
#  2027  1571.476497  1626.575705  3.132900e+10  1.867440e+11  199.964832
#  2028  1625.393882  1475.703735  2.448168e+10  1.694427e+11  205.165115
#  2029  1478.653270  1446.033650  3.143600e+10  1.660555e+11  151.049638
#  2030  1446.929455  1459.973121  2.074210e+10  1.676759e+11   91.145499
#
#         Percent
#  0     3.915926
#  1     1.398319
#  2     1.146585
#  3     1.705896
#  4     1.459856
#  ...        ...
#  2026  1.291961
#  2027  1.132338
#  2028  1.140039
#  2029  1.107281
#  2030  1.063570
#
#  [2031 rows x 12 columns])

# %%
avglows = np.array(getavgl(coins))  
avghighs = np.array(getavgh(coins))
swings = avghighs/avglows

avglows, \
avghighs, \
swings
# Out:
# (array([4695.10302717,   40.05807784,    0.19209553,   60.20976877,
#          246.98644965]),
#  array([4974.04023863,   43.62769938,    0.21161514,   65.80488579,
#          267.06803366]),
#  array([1.05941024, 1.08911115, 1.1016141 , 1.09292706, 1.08130642]))

# %%
labels = ['BTC', 'LTC', 'XRP', 'XMR', 'ETH']


x = labels  # the label locations
y = swings
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
ax.bar(x, y, label='Avg Daily High/ Avg Daily Low')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Average Daily Percentage Change')
ax.set_title('Average Variance across 5 Cryptocurrencies')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
ax.set_ylim((1, 1.15))

fig.tight_layout()

plt.show()

# %%
#coins = btc, ltc, xrp, xmr, eth      #variable that holds all data for the 5 dataframes

#avglows = (getavg(coins))         #



xlows = np.array([4695.103027174673,
 40.05807784362007,
 0.1920955266346204,
 60.209768769358284,
 246.98644965038866])

xhighs = np.array([4974.040238625122,
 43.62769937740703,
 0.21161513993320402,
 65.80488578695243,
 267.0680336615071])

avglows

xswing = xlows/xhighs
xswing
# Out:
# array([0.9439214 , 0.91817993, 0.9077589 , 0.91497414, 0.92480723])

# %%
type(btc.iloc[0,3])  #I'm curious about doing some date/time stuff here

#btc.iloc[0,3][:7] == '2013-04' ## this would now identifies the STRING for the month of April 2013 :)

btc.iloc[0,3][:7]
# Out:
# '2013-04'

# %%
def higherlower(df):  
    higher = 0  #counting days where the price was higher at close than at open
    lower = 0   #counting days where the price was lower at close than at open
    for index, row in df.iterrows():
        if df.loc[index,'Close'] > df.loc[index,'Open']:
            higher += 1
        elif df.loc[index,'Close'] == df.loc[index,'Open']:
            pass
        else:
            lower +=1
    return higher, lower, higher/lower

# %%
testset = btc.iloc[:5,:]   #a few test sets to test my higherlower counter thing
testset
test2 = btc.iloc[6:20,:]
test2

test3 = btc.iloc[20:40,:]
test3
# Out:
#     SNo     Name Symbol                 Date        High         Low  \
# 20   21  Bitcoin    BTC  2013-05-19 23:59:59  124.500000  119.570999
# 21   22  Bitcoin    BTC  2013-05-20 23:59:59  123.621002  120.120003
# 22   23  Bitcoin    BTC  2013-05-21 23:59:59  123.000000  121.209999
# 23   24  Bitcoin    BTC  2013-05-22 23:59:59  124.000999  122.000000
# 24   25  Bitcoin    BTC  2013-05-23 23:59:59  126.933998  123.099998
# 25   26  Bitcoin    BTC  2013-05-24 23:59:59  133.850006  125.719002
# 26   27  Bitcoin    BTC  2013-05-25 23:59:59  133.218994  128.899994
# 27   28  Bitcoin    BTC  2013-05-26 23:59:59  136.000000  130.615005
# 28   29  Bitcoin    BTC  2013-05-27 23:59:59  135.464996  124.699997
# 29   30  Bitcoin    BTC  2013-05-28 23:59:59  130.580002  125.599998
# 30   31  Bitcoin    BTC  2013-05-29 23:59:59  132.589996  127.662003
# 31   32  Bitcoin    BTC  2013-05-30 23:59:59  132.250000  127.000000
# 32   33  Bitcoin    BTC  2013-05-31 23:59:59  129.899994  126.400002
# 33   34  Bitcoin    BTC  2013-06-01 23:59:59  129.779999  127.198997
# 34   35  Bitcoin    BTC  2013-06-02 23:59:59  129.399994  115.050003
# 35   36  Bitcoin    BTC  2013-06-03 23:59:59  122.500000  116.000000
# 36   37  Bitcoin    BTC  2013-06-04 23:59:59  123.839996  119.099998
# 37   38  Bitcoin    BTC  2013-06-05 23:59:59  123.469002  119.899002
# 38   39  Bitcoin    BTC  2013-06-06 23:59:59  123.099998  117.250000
# 39   40  Bitcoin    BTC  2013-06-07 23:59:59  119.000000  106.419998
#
#           Open       Close  Volume     Marketcap      Swing   Percent
# 20  123.210999  121.989998     0.0  1.363205e+09   4.929001  1.041222
# 21  122.500000  122.000000     0.0  1.363710e+09   3.500999  1.029146
# 22  122.019997  122.879997     0.0  1.374013e+09   1.790001  1.014768
# 23  122.889999  123.889000     0.0  1.385779e+09   2.000999  1.016402
# 24  123.800003  126.699997     0.0  1.417770e+09   3.834000  1.031145
# 25  126.300003  133.199997     0.0  1.491071e+09   8.131004  1.064676
# 26  133.100006  131.979996     0.0  1.477958e+09   4.319000  1.033507
# 27  131.985992  133.479996     0.0  1.495293e+09   5.384995  1.041228
# 25  3.17948     0.0  5.701747e+07  0.14892  1.049042
# 26  3.11869     0.0  5.602634e+07  0.14066  1.046046
# 27  3.24890     0.0  5.845796e+07  0.24009  1.077767
# 28  3.10091     0.0  5.588213e+07  0.24279  1.080421
# 29  3.09213     0.0  5.581373e+07  0.11058  1.036623

# %%
higherlower(change)
higherlower(change2)  #woooorking, now I'm thinking we could pull by month if we wanted
# Out:
# (8, 7, 1.1428571428571428)

# %%
a = higherlower(btc) #the most up days, rank 1 
a
# Out:
# (1547, 1314, 1.1773211567732116)

# %%
b = higherlower(ltc) #rank 4

# %%
c = higherlower(xmr)   #ok, so this means xmr is a "safer" bet and has more "up" days vs ltc, etc rank 3

# %%
d = higherlower(xrp) #rank 5

# %%
e = higherlower(eth)   #this is second best, rank 2

# %%
higherlowernums = (a, b, c, d, e)

dailyhighlow =  1.1773211567732116, 0.9233870967741935, 0.9911433172302737, 0.8989690721649485, 0.9931305201177625
type(dailyhighlow)
# Out:
# tuple

# %%
#gonna try some plots, lawd help me

# %%
fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot(range(len(btc)), btc['Low'])  # Plot some data on the axes.
ax.plot(range(len(btc)), btc['High']) 
ax.set_title('Daily High/Low of Btc, 2013-2021')
# Out:
# Text(0.5, 1.0, 'Daily High/Low of Btc, 2013-2021')

# %%
z = np.array([a,b,c,d,e])
z
# Out:
# array([[1547.        , 1314.        ,    1.17732116],
#        [1374.        , 1488.        ,    0.9233871 ],
#        [1231.        , 1242.        ,    0.99114332],
#        [1308.        , 1455.        ,    0.89896907],
#        [1012.        , 1019.        ,    0.99313052]])

# %%
highers = z[:,:1]
lowers = z[:, 1:2]
change = z[:,2:3]

highers
lowers
change
# Out:
# array([[1.17732116],
#        [0.9233871 ],
#        [0.99114332],
#        [0.89896907],
#        [0.99313052]])

# %%
# Import Dataset
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mtcars.csv")

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of mtcars', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
labels = ['BTC', 'LTC', 'XRP', 'XMR', 'ETH']
high = highers.squeeze()
low = lowers.squeeze()

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, high, width, label='Highs')
rects2 = ax.bar(x + width/2, low, width, label='Lows')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Up/Down Days')
ax.set_title('Opening: Higher or Lower than Closing')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylim(bottom= 900)
ax.legend()


fig.tight_layout()

plt.show()   #dis chart shows up/down days smwhat clearly; .squeeze() i don't get what u do but thanks i need u :)

# %%
### you are now entering correlation country ###  
 # lets face it, theres not going to be a whole lot from the price data.
    #we look at high/low days, I WILL look at percentage swings somehow
    #what do we correlate? price, swing, percent, marketcap? lets do them all ?

# %%
#What does a basica Pearson correlation look like? Lets find out#

#Lets see how correlated BTC AND LTC 

# ct1a = btc['Low'].squeeze()
# ct1b = ltc['Low'].squeeze()
# ct1c = xrp['Low']
# ct1d = xmr['Low']
# ct1e = eth['Low']

# %%
# stats.pearsonr(ct1a, ct1c)

# %%
#ok, i'm realizing that the datasets are different lengths. Going to shorten to standardize, then try to compare.

#8/8/2015 is the start date, len should be 2031 for now. I'm gonna try slicing before SQL and shit.

#MAGIC LEN = 2031 *****

# %%
btctrim= btc['Low'].iloc[831:]

# %%
# len(ct1c)

# %%
#stats.pearsonr(btctrim, ct1e)

# %%
#note on correlation- we have a few metrics to correlate on:
    #open close high low volume cap swing percent should i write a "getpearson" func? 
    # probably yes, but I think the
    #mvp/ smartest thing would be percentage change even though price data is far easier - if I want to 
    # compare any coins against something, I will HAVE to calculate percentage change vs just grab prices.
    #The thing to note is that percent change is caclulated 
    #######    off daily High/Low rather than the change from open/close ######### 
    # which could be another interesting column to add and analyize if possible/neccessary ** 
    
    #What are the yardsticks to compare it to? GOLD/Other precious metals, GDP, Oil/Gas? 
    #Commodities - Gold, oil, coffee
    #ETFS: Shares (GLD) and iShares Gold Trust (IAU)
    
    #hint - lets start simple :)
    
    # first go-round will examine correlation of PRICE INFO (not rate of change), delta will come later.

# %%
# lets trim all df down to magic num len: 2031.

len(btctrim)
ltctrim = ltc['Low'].iloc[831:]
len(ltctrim)
xrptrim = xrp['Low'].iloc[733:]
len(xrptrim)
xmrtrim = xmr['Low'].iloc[442:]
len(xmrtrim)
ethtrim = eth['Low']
len(ethtrim)
# lets hit correlation country
type(btctrim)
# Out:
# pandas.core.series.Series

# %%
trims = btctrim, ltctrim, xrptrim, xmrtrim, ethtrim
type(trims)
# Out:
# tuple

# %%
stats.pearsonr(btctrim, ltctrim)
# Out:
# (0.6881281662082426, 5.648609214400735e-285)

# %%
stats.pearsonr(btctrim, xrptrim)
# Out:
# (0.4210843444576242, 4.2554831144728555e-88)

# %%
stats.pearsonr(btctrim, xmrtrim)
# Out:
# (0.6068718830927121, 1.2235250437701414e-204)

# %%
stats.pearsonr(btctrim, ethtrim)
# Out:
# (0.8624653045131635, 0.0)

# %%
type(trims)
# Out:
# tuple

# %%
# I'm a little concerned BTC/ETH (highest correlation) has the lowest p-val

# %%
stats.pearsonr(ltctrim, xrptrim)
# Out:
# (0.8279949442801359, 0.0)

# %%
stats.pearsonr(ltctrim, xmrtrim)
# Out:
# (0.9392509325781944, 0.0)

# %%
stats.pearsonr(ltctrim, ethtrim)
# Out:
# (0.8439159889989176, 0.0)

# %%
## break  
## these are the values for correlation (10)
corrs =  (.6881281662082426, .4210843444576242, 
         .6068718830927121, .8624653045131635,
         .8279949442801359, .9392509325781944,
         .8439159889989176, .8773117141612505,
         .674485401720506, .8267110509300152)

type(corrs)
# Out:
# tuple

# %%
stats.pearsonr(xrptrim, xmrtrim)
# Out:
# (0.8773117141612505, 0.0)

# %%
stats.pearsonr(xrptrim, ethtrim)
# Out:
# (0.674485401720506, 1.1204809989951876e-269)

# %%
#break

# %%
stats.pearsonr(ethtrim, xmrtrim)
# Out:
# (0.8267110509300152, 0.0)

# %%
## This is all combinations of 5 choose 2 = 10

## highest correlations -  btc/eth (862), ltc/xmr (939), xrp/xmr (877)

### lowest correlations - btc/xrp (42), btc/xmr (606), xrp/eth (674)

##regression plot 


#coef = np.polyfit(x,y,1)
#poly1d_fn = np.poly1d(coef) 

##check out correlation matrix plots and get one :)

# %%
btctrim
# Out:
# 831       260.709991
# 832       260.467987
# 833       262.596008
# 834       264.093994
# 835       265.468994
#             ...
# 2857    45290.590268
# 2858    47213.498162
# 2859    47093.853019
# 2860    44454.842114
# 2861    45269.025766
# Name: Low, Length: 2031, dtype: float64

# %%
# # Import Dataset
# df = mydf

# # Plot
# plt.figure(figsize=(12,10), dpi= 80)
# sns.heatmap(mydf.corr(), xticklabels=mydf.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# # Decorations
# plt.title('Correlogram of mtcars', fontsize=22)
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# plt.show()

# %%
#trimmed = pd.DataFrame(btctrim, ltctrim, xrptrim, xmrtrim, ethtrim)

# %%
testdic = {'BTC': btctrim.reset_index(drop=True), 'LTC': ltctrim.reset_index(drop=True), 'XRP': xrptrim.reset_index(drop=True), 'XMR': xmrtrim.reset_index(drop=True), 'ETH': ethtrim}
testdic
trimmed_df = pd.DataFrame(testdic)
trimmed_df.corr()
# Out:
#           BTC       LTC       XRP       XMR       ETH
# BTC  1.000000  0.688128  0.421084  0.606872  0.862465
# LTC  0.688128  1.000000  0.827995  0.939251  0.843916
# XRP  0.421084  0.827995  1.000000  0.877312  0.674485
# XMR  0.606872  0.939251  0.877312  1.000000  0.826711
# ETH  0.862465  0.843916  0.674485  0.826711  1.000000

# %%
#btctrim.reset_index(drop=True)

# %%
# Import Dataset
df = trimmed_df

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(trimmed_df.corr(), xticklabels=trimmed_df.corr().columns, yticklabels=trimmed_df.corr().columns, cmap='mako', center=0, annot=True)

# Decorations
plt.title('Correlation from Daily Lows', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
#lets grab daily highs and compare the correlation?

ahigh = btc['High'].iloc[831:]
bhigh = ltc['High'].iloc[831:]
chigh = xrp['High'].iloc[733:]
dhigh = xmr['High'].iloc[442:]
ehigh = eth['High']

# %%
len(chigh)
# Out:
# 2031

# %%
highdict = {'BTC': ahigh.reset_index(drop=True), 'LTC': bhigh.reset_index(drop=True), 'XRP': chigh.reset_index(drop=True), 'XMR': dhigh.reset_index(drop=True), 'ETH': ehigh}
highdict
highframe = pd.DataFrame(highdict)

highframe.corr()

type(highframe)
# Out:
# pandas.core.frame.DataFrame

# %%
# Import Dataset
df = highframe

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(highframe.corr(), xticklabels=highframe.corr().columns, yticklabels=highframe.corr().columns, cmap='rocket', center=0, annot=True)

# Decorations
plt.title('Correlation from Daily Highs', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
highlowcomparison = highframe / trimmed_df

# %%
highlowcomparison.corr()
# Out:
#           BTC       LTC       XRP       XMR       ETH
# BTC  1.000000  0.699078  0.396935  0.504828  0.388574
# LTC  0.699078  1.000000  0.514094  0.419860  0.334974
# XRP  0.396935  0.514094  1.000000  0.298468  0.230860
# XMR  0.504828  0.419860  0.298468  1.000000  0.389764
# ETH  0.388574  0.334974  0.230860  0.389764  1.000000

# %%
# Import Dataset
df = highlowcomparison

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(highlowcomparison.corr(), xticklabels=highlowcomparison.corr().columns, yticklabels=highlowcomparison.corr().columns, cmap='magma', center=0, annot=True)

# Decorations
plt.title('Correlation of Daily Delta: High/Low', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
# X = 
# Y1 = X + 2*np.random.random(X.shape)
# Y2 = X**2 + np.random.random(X.shape)

# plt.scatter(X,Y1,color='k')
# plt.scatter(X,Y2,color='g')
# plt.show()

# %%
#lets grab daily swings and compare the correlation?

aswing = btc['Swing'].iloc[831:]
bswing = ltc['Swing'].iloc[831:]
cswing = xrp['Swing'].iloc[733:]
dswing = xmr['Swing'].iloc[442:]
eswing = eth['Swing']

# %%
len(aswing)
len(cswing)
# Out:
# 2031

# %%
swingdict = {'BTC': aswing.reset_index(drop=True), 'LTC': bswing.reset_index(drop=True), 'XRP': cswing.reset_index(drop=True), 'XMR': dswing.reset_index(drop=True), 'ETH': eswing}
swingdict


swingframe = pd.DataFrame(swingdict)

swingframe.corr()
# Out:
#           BTC       LTC       XRP       XMR       ETH
# BTC  1.000000  0.639669  0.369205  0.548324  0.805810
# LTC  0.639669  1.000000  0.603974  0.811947  0.756724
# XRP  0.369205  0.603974  1.000000  0.689031  0.583961
# XMR  0.548324  0.811947  0.689031  1.000000  0.725040
# ETH  0.805810  0.756724  0.583961  0.725040  1.000000

# %%
# Import Dataset
df = swingframe

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(swingframe.corr(), xticklabels=swingframe.corr().columns, yticklabels=swingframe.corr().columns, cmap='coolwarm', center=0, annot=True)

# Decorations
plt.title('Correlation of daily "Swing" (daily high - daily low)', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
#lets grab daily percents and compare the correlation?

adelta = btc['Percent'].iloc[831:]
bdelta = ltc['Percent'].iloc[831:]
cdelta = xrp['Percent'].iloc[733:]
ddelta = xmr['Percent'].iloc[442:]
edelta = eth['Percent']

# %%
len(adelta)
len(cdelta)
# Out:
# 2031

# %%
deltadict = {'BTC': adelta.reset_index(drop=True), 'LTC': bdelta.reset_index(drop=True), 'XRP': cdelta.reset_index(drop=True), 'XMR': ddelta.reset_index(drop=True), 'ETH': edelta}
deltadict


deltaframe = pd.DataFrame(deltadict)

deltabtc = deltaframe['BTC']
deltaltc = deltaframe['LTC']
deltaxrp = deltaframe['XRP']
deltaxmr = deltaframe['XMR']
deltaeth = deltaframe['ETH']

# %%
# Import Dataset
df = deltaframe

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(deltaframe.corr(), xticklabels=deltaframe.corr().columns, yticklabels=deltaframe.corr().columns, cmap='coolwarm', center=0, annot=True)

# Decorations
plt.title('Correlation of daily "Delta" (daily high/daily low)', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
##smaller correlation matrixes ##

top3dict = {'XRP': cdelta.reset_index(drop=True), 'XMR': ddelta.reset_index(drop=True), 'ETH': edelta}
top3dict


top3frame = pd.DataFrame(top3dict)

deltaxrp = top3frame['XRP']
deltaxmr = top3frame['XMR']
deltaeth = top3frame['ETH']

# %%
# Import Dataset
df = top3frame

# Plot
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(top3frame.corr(), xticklabels=top3frame.corr().columns, yticklabels=top3frame.corr().columns, cmap='coolwarm', center=0, annot=True)

# Decorations
plt.title('Correlation of daily "Delta" (daily high/daily low) of XRP, XMR, ETH', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
eth['Date']

# eth.iloc[0,3][:7]

# def listdates(frame):
#     lst = []
#     for i, v in enumerate(frame):
#         lst.append(eth.iloc[i,3][:7])
        
#     return lst

#listdates(eth)

dates = eth['Date']
len(dates)

dates

# def listdates(frame):
#     lst = []
#     for i, v in enumerate(frame):
#         lst.append(frame.iloc[i,3][:7])
        
#     return lst

# listdates(dates)
# Out:
# 0       2015-08-08 23:59:59
# 1       2015-08-09 23:59:59
# 2       2015-08-10 23:59:59
# 3       2015-08-11 23:59:59
# 4       2015-08-12 23:59:59
#                ...
# 2026    2021-02-23 23:59:59
# 2027    2021-02-24 23:59:59
# 2028    2021-02-25 23:59:59
# 2029    2021-02-26 23:59:59
# 2030    2021-02-27 23:59:59
# Name: Date, Length: 2031, dtype: object

# %%
# #attempt to plot the daily delta numbers for 2031 instances


# #X = np.arange(1,2032)
# X = dates
# Y1 = deltabtc 
# Y2 = deltaltc
# Y3 = deltaxrp
# Y4 = deltaxmr
# Y5 = deltaeth
# s = 5
# plt.figure(figsize=(20,5)) 
# aa1 = plt.scatter(X,Y1,color='darkblue', alpha = .7, s=s)
# aa2 = plt.scatter(X,Y2,color='yellow', alpha = .5, s=s)
# aa3 = plt.scatter(X,Y3,color='green', alpha = .4, s=s)
# aa4 = plt.scatter(X,Y4,color='red', alpha = .2, s=s)
# aa5 = plt.scatter(X,Y5,color='pink', alpha = .2, s=s)
# plt.legend((aa1, aa2, aa3, aa4, aa5),('BTC', 'LTC','XRP', 'XMR', 'ETH'),numpoints=1, loc='upper right', ncol=3, fontsize=8)
# plt.title(" 'Daily Deltas' (daily high/daily low) for 5 Cryptocurrencies")
# plt.xticks(rotation = 45)
# plt.show()

# %%
len(range(1,2032))
# Out:
# 2031

# %%
start = pd.Timestamp('2015-08-08 23:59:59')
end = pd.Timestamp('2021-02-27 23:59:59')
t = np.linspace(start.value, end.value, 2031)
t = pd.to_datetime(t)
type(t)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
# def justdates(frame):
#     f

# %%
#attempt to plot the daily delta numbers for 2031 instances
fig, ax = plt.subplots(figsize=(20,5))

#X = np.arange(1,2032)
X = t
Y1 = deltabtc 
Y2 = deltaltc
Y3 = deltaxrp
Y4 = deltaxmr
Y5 = deltaeth
s = 15 
aa1 = ax.scatter(X,Y1,color='darkgreen', alpha = .9, s=s)
aa2 = ax.scatter(X,Y2,color='yellow', alpha = .5, s=s)
aa3 = ax.scatter(X,Y3,color='chartreuse', alpha = .4, s=s)
aa4 = ax.scatter(X,Y4,color='purple', alpha = .5, s=s)
aa5 = ax.scatter(X,Y5,color='cyan', alpha = .4, s=s)
ax.set_title(" 'Daily Deltas' (daily high/daily low) for 5 Cryptocurrencies", fontsize=25)
ax.set_ylim(1, 2.5)
ax.legend((aa1, aa2, aa3, aa4, aa5),('BTC', 'LTC','XRP', 'XMR', 'ETH'),numpoints=1, loc='upper right', ncol=3, fontsize=20)

# %%
#attempt to plot the daily delta numbers for 2031 instances
fig, ax = plt.subplots(figsize=(20,5))

#X = np.arange(1,2032)
X = t

Y3 = deltaxrp
Y4 = deltaxmr
Y5 = deltaeth
s = 15 
aa3 = ax.scatter(X,Y3,color='chartreuse', alpha = .8, s=s)
aa4 = ax.scatter(X,Y4,color='purple', alpha = .6, s=s)
aa5 = ax.scatter(X,Y5,color='cyan', alpha = .3, s=s)
ax.set_title(" 'Daily Deltas' (daily high/daily low) of XRP, XRM, ETH", fontsize=25)
ax.set_ylim(1, 2.5)
ax.legend((aa3, aa4, aa5),('XRP', 'XMR', 'ETH'),numpoints=1, loc='upper right', ncol=3, fontsize=20)
